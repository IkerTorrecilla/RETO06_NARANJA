# %%
import pandas as pd
import os
import missingno as msno
import numpy as np
from datetime import datetime
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
path = os.path.join("/home/eneko/Documentos/RETO_06/datos/df_limpio.csv")
reservas = pd.read_csv(path)
reservas
# Out:
#                  booked_at         checkin_time        checkout_time  \
# 0      2022-11-26 16:10:00  2023-01-01 12:00:00  2023-01-02 12:00:00
# 1      2022-12-21 17:27:00  2023-01-01 13:09:00  2023-01-10 12:00:00
# 2      2022-09-21 19:46:00  2023-01-01 15:00:00  2023-01-07 12:00:00
# 3      2022-09-24 12:09:00  2023-01-01 15:00:00  2023-01-02 12:00:00
# 4      2022-10-18 07:12:00  2023-01-01 15:00:00  2023-01-02 12:00:00
# ...                    ...                  ...                  ...
# 52094  2023-10-10 20:53:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 52095  2023-10-13 13:38:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 52096  2023-10-17 08:36:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 52097  2023-10-17 08:36:00  2023-12-31 15:00:00  2024-01-01 11:00:00
# 52098  2023-12-30 08:02:00  2023-12-31 15:00:00  2024-01-02 11:00:00
#
#        lead_time  lenght_of_stay checkin_month checkin_day  adult_count  \
# 0             36               1       January      Sunday            1
# 1             11               9       January      Sunday            1
# 2            102               6       January      Sunday            2
# 3             99               1       January      Sunday            2
# 4             75               1       January      Sunday            4
# ...          ...             ...           ...         ...          ...
# 52094         82               1      December      Sunday            4
# 52095         79               1      December      Sunday            4
# 52096         75               1      December      Sunday            5
# 52097         75               1      December      Sunday            4
# 52098          1               2      December      Sunday            2
#
#        child_count           origin  ... momento_checkin ratio_asistencia  \
# 0                0  channel_manager  ...           antes         1.000000
# 1                0  channel_manager  ...           antes         1.000000
# 2                4  channel_manager  ...           antes         0.333333
# 3                2  channel_manager  ...           antes         0.500000
# 4                0  channel_manager  ...           antes         1.000000
# ...            ...              ...  ...             ...              ...
# 52094            0  channel_manager  ...     cancelacion         0.000000
# 52095            0        telephone  ...           antes         1.000000
# 52096            0   direct_channel  ...           antes         1.000000
# 52097            0   direct_channel  ...           antes         1.000000
# 52098            0   direct_channel  ...     cancelacion         0.000000
#
#       ratio_cancelaciones_mes_respecto_reservas zona_roja estacion_estancia  \
# 0                                      0.251273         1          invierno
# 1                                      0.251273         1          invierno
# 2                                      0.251273         1          invierno
# 3                                      0.251273         1          invierno
# 4                                      0.251273         1          invierno
# ...                                         ...       ...               ...
# 52094                                  0.239947         0          invierno
# 52095                                  0.239947         0          invierno
# 52096                                  0.239947         0          invierno
# 52097                                  0.239947         0          invierno
# 52098                                  0.239947         0          invierno
#
#       estacion_reserva  antiguedad_hotel_en_dias es_festivo es_finde      city
# 0                otoño                      2110      False    False  Donostia
# 1             invierno                      2110       True    False  Donostia
# 2                otoño                      2110       True    False  Donostia
# 3                otoño                      2110      False    False  Donostia
# 4                otoño                      2110      False    False  Donostia
# ...                ...                       ...        ...      ...       ...
# 52094            otoño                      1198      False    False  Pamplona
# 52095            otoño                      1198      False    False  Pamplona
# 52096            otoño                      1198      False    False  Pamplona
# 52097            otoño                      1198      False    False  Pamplona
# 52098         invierno                      1198      False    False  Pamplona
#
# [52099 rows x 44 columns]

# %%
meteorologia = pd.read_csv("/home/eneko/Documentos/RETO_06/datos/meteo.csv",decimal=',',na_values=['', 'NA', 'NaN', None])
meteorologia
# Out:
#       Unnamed: 0       fecha indicativo                nombre provincia  \
# 0              0  2023-01-01       1082     BILBAO AEROPUERTO   BIZKAIA
# 1              1  2023-01-02       1082     BILBAO AEROPUERTO   BIZKAIA
# 2              2  2023-01-03       1082     BILBAO AEROPUERTO   BIZKAIA
# 3              3  2023-01-04       1082     BILBAO AEROPUERTO   BIZKAIA
# 4              4  2023-01-05       1082     BILBAO AEROPUERTO   BIZKAIA
# ...          ...         ...        ...                   ...       ...
# 5503        5503  2024-08-27      9263D  PAMPLONA, AEROPUERTO   NAVARRA
# 5504        5504  2024-08-28      9263D  PAMPLONA, AEROPUERTO   NAVARRA
# 5505        5505  2024-08-29      9263D  PAMPLONA, AEROPUERTO   NAVARRA
# 5506        5506  2024-08-30      9263D  PAMPLONA, AEROPUERTO   NAVARRA
# 5507        5507  2024-08-31      9263D  PAMPLONA, AEROPUERTO   NAVARRA
#
#       altitud  tmed  prec  tmin horatmin  ...  presMax horaPresMax presMin  \
# 0          42  19.2   5,1  13.4    23:20  ...   1014.9          00  1008.5
# 1          42   9.8   0,0   5.0    23:57  ...   1025.8      Varias  1012.2
# 2          42   9.1   0,0   3.2    05:27  ...   1029.5      Varias  1025.4
# 3          42  10.6   0,0   3.4    06:09  ...   1031.2      Varias  1028.5
# 4          42  11.5   0,0   5.3    23:33  ...   1029.3          00  1021.7
# ...       ...   ...   ...   ...      ...  ...      ...         ...     ...
# 5503      459  22.2   0,0  12.5    04:38  ...    965.3          00   961.9
# 5504      459  27.5   0,0  19.4    23:59  ...    964.8          23   959.5
# 5505      459  22.9  13,4  17.3    08:13  ...    968.3      Varias   962.8
# 5506      459  23.4  10,3  17.6    03:57  ...    965.4          00   962.1
# 5507      459  23.4  24,6  16.2    05:23  ...    964.6      Varias   960.9
#
#       horaPresMin  hrMedia hrMax  horaHrMax  hrMin horaHrMin      city
# 0              16     36.0  92.0      23:59   26.0     15:24    Bilbao
# 1              00     80.0  95.0     Varias   53.0     13:58    Bilbao
# 2              01     76.0  97.0      07:00   43.0     14:51    Bilbao
# 3              15     72.0  89.0     Varias   46.0     14:14    Bilbao
# 4              20     72.0  93.0     Varias   48.0     13:17    Bilbao
# ...           ...      ...   ...        ...    ...       ...       ...
# 5503           13      NaN  94.0      05:15   37.0     15:55  Pamplona
# 5504           16      NaN  85.0     Varias   29.0     12:58  Pamplona
# 5505           17     81.0  98.0     Varias   58.0     14:11  Pamplona
# 5506           17      NaN  97.0     Varias   53.0     13:17  Pamplona
# 5507           15     77.0  98.0     Varias   42.0     13:56  Pamplona
#
# [5508 rows x 27 columns]

# %%
msno.matrix(meteorologia)

# %%
meteorologia.isna().sum()
# Out:
# Unnamed: 0      0
# fecha           0
# indicativo      0
# nombre          0
# provincia       0
# altitud         0
# tmed           16
# prec            0
# tmin           16
# horatmin       16
# tmax           10
# horatmax       10
# dir            17
# velmedia       19
# racha          17
# horaracha      17
# sol             7
# presMax        14
# horaPresMax    14
# presMin        14
# horaPresMin    14
# hrMedia        28
# hrMax          22
# horaHrMax      22
# hrMin          21
# horaHrMin      21
# city            0
# dtype: int64

# %%
#VER DUPLICADOS
columnas_duplicados = ['city', 'fecha']
duplicados = meteorologia[meteorologia.duplicated(subset=columnas_duplicados, keep=False)]
duplicados
# Out:
#       Unnamed: 0       fecha indicativo                               nombre  \
# 180          180  2023-06-30       1082                    BILBAO AEROPUERTO
# 181          181  2023-06-30       1082                    BILBAO AEROPUERTO
# 361          361  2023-12-27       1082                    BILBAO AEROPUERTO
# 362          362  2023-12-27       1082                    BILBAO AEROPUERTO
# 542          542  2024-06-24       1082                    BILBAO AEROPUERTO
# 543          543  2024-06-24       1082                    BILBAO AEROPUERTO
# 792          792  2023-06-30      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 793          793  2023-06-30      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 973          973  2023-12-27      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 974          974  2023-12-27      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 1154        1154  2024-06-24      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 1155        1155  2024-06-24      1014A  DONOSTIA / SAN SEBASTIÁN AEROPUERTO
# 1404        1404  2023-06-30      9091R           VITORIA-GASTEIZ AEROPUERTO
# 1405        1405  2023-06-30      9091R           VITORIA-GASTEIZ AEROPUERTO
# 1585        1585  2023-12-27      9091R           VITORIA-GASTEIZ AEROPUERTO
# 1586        1586  2023-12-27      9091R           VITORIA-GASTEIZ AEROPUERTO
# 1766        1766  2024-06-24      9091R           VITORIA-GASTEIZ AEROPUERTO
# 1767        1767  2024-06-24      9091R           VITORIA-GASTEIZ AEROPUERTO
# 2016        2016  2023-06-30      8414A                  VALENCIA AEROPUERTO
# 2017        2017  2023-06-30      8414A                  VALENCIA AEROPUERTO
# 2197        2197  2023-12-27      8414A                  VALENCIA AEROPUERTO
# 2198        2198  2023-12-27      8414A                  VALENCIA AEROPUERTO
# 2378        2378  2024-06-24      8414A                  VALENCIA AEROPUERTO
# 2379        2379  2024-06-24      8414A                  VALENCIA AEROPUERTO
# 2628        2628  2023-06-30       3129                    MADRID AEROPUERTO
# 2629        2629  2023-06-30       3129                    MADRID AEROPUERTO
# 2809        2809  2023-12-27       3129                    MADRID AEROPUERTO
# 2810        2810  2023-12-27       3129                    MADRID AEROPUERTO
# 2990        2990  2024-06-24       3129                    MADRID AEROPUERTO
# 2991        2991  2024-06-24       3129                    MADRID AEROPUERTO
# 3240        3240  2023-06-30      6155A                    MÁLAGA AEROPUERTO
# 3241        3241  2023-06-30      6155A                    MÁLAGA AEROPUERTO
# 3421        3421  2023-12-27      6155A                    MÁLAGA AEROPUERTO
# 3422        3422  2023-12-27      6155A                    MÁLAGA AEROPUERTO
# 3602        3602  2024-06-24      6155A                    MÁLAGA AEROPUERTO
# 3603        3603  2024-06-24      6155A                    MÁLAGA AEROPUERTO
# 3852        3852  2023-06-30      5530E                   GRANADA AEROPUERTO
# 3853        3853  2023-06-30      5530E                   GRANADA AEROPUERTO
# 4033        4033  2023-12-27      5530E                   GRANADA AEROPUERTO
# 4034        4034  2023-12-27      5530E                   GRANADA AEROPUERTO
# 4214        4214  2024-06-24      5530E                   GRANADA AEROPUERTO
# 4215        4215  2024-06-24      5530E                   GRANADA AEROPUERTO
# 4464        4464  2023-06-30       5402                   CÓRDOBA AEROPUERTO
# 4465        4465  2023-06-30       5402                   CÓRDOBA AEROPUERTO
# 4645        4645  2023-12-27       5402                   CÓRDOBA AEROPUERTO
# 4646        4646  2023-12-27       5402                   CÓRDOBA AEROPUERTO
# 4826        4826  2024-06-24       5402                   CÓRDOBA AEROPUERTO
# 4827        4827  2024-06-24       5402                   CÓRDOBA AEROPUERTO
# 5076        5076  2023-06-30      9263D                 PAMPLONA, AEROPUERTO
# 5077        5077  2023-06-30      9263D                 PAMPLONA, AEROPUERTO
# 5257        5257  2023-12-27      9263D                 PAMPLONA, AEROPUERTO
# 5258        5258  2023-12-27      9263D                 PAMPLONA, AEROPUERTO
# 5438        5438  2024-06-24      9263D                 PAMPLONA, AEROPUERTO
# 5439        5439  2024-06-24      9263D                 PAMPLONA, AEROPUERTO
#
#         provincia  altitud  tmed prec  tmin horatmin  ...  presMax  \
# 180       BIZKAIA       42  18.4  0,4  14.5    03:43  ...   1020.2
# 181       BIZKAIA       42  18.4  0,4  14.5    03:43  ...   1020.2
# 361       BIZKAIA       42  12.0  0,0   4.4    00:17  ...   1017.2
# 362       BIZKAIA       42  12.0  0,0   4.4    00:17  ...   1017.2
# 542       BIZKAIA       42  20.0  0,0  15.1    23:56  ...   1015.2
# 543       BIZKAIA       42  20.0  0,0  15.1    23:56  ...   1015.2
# 792      GIPUZKOA        4  20.4  0,0  17.6    01:59  ...   1023.2
# 793      GIPUZKOA        4  20.4  0,0  17.6    01:59  ...   1023.2
# 973      GIPUZKOA        4  11.6  0,0   2.2    05:31  ...   1020.5
# 974      GIPUZKOA        4  11.6  0,0   2.2    05:31  ...   1020.5
# 1154     GIPUZKOA        4  21.3  0,0  17.5    04:20  ...   1018.7
# 1155     GIPUZKOA        4  21.3  0,0  17.5    04:20  ...   1018.7
# 1404  ARABA/ALAVA      513  16.0  0,1  12.5    03:57  ...    964.9
# 1405  ARABA/ALAVA      513  16.0  0,1  12.5    03:57  ...    964.9
# 1585  ARABA/ALAVA      513   4.1  0,0  -2.7    00:50  ...    964.2
# 1586  ARABA/ALAVA      513   4.1  0,0  -2.7    00:50  ...    964.2
# 1766  ARABA/ALAVA      513  17.8  0,0  11.9    23:49  ...    960.2
# 1767  ARABA/ALAVA      513  17.8  0,0  11.9    23:49  ...    960.2
# 2016     VALENCIA       56  25.7  0,0  22.2    23:49  ...   1010.2
# 2017     VALENCIA       56  25.7  0,0  22.2    23:49  ...   1010.2
# 2197     VALENCIA       56   9.2  0,0  -0.4    07:12  ...   1018.4
# 2198     VALENCIA       56   9.2  0,0  -0.4    07:12  ...   1018.4
# 2378     VALENCIA       56  25.2  0,0  22.1    06:18  ...   1008.6
# 2379     VALENCIA       56  25.2  0,0  22.1    06:18  ...   1008.6
# 2628       MADRID      609  23.6  0,0  16.3    05:10  ...    953.3
# 2629       MADRID      609  23.6  0,0  16.3    05:10  ...    953.3
# 2809       MADRID      609   4.0  0,0  -3.5    05:45  ...    958.2
# 2810       MADRID      609   4.0  0,0  -3.5    05:45  ...    958.2
# 2990       MADRID      609  25.1  0,0  16.4    04:51  ...    948.8
# 2991       MADRID      609  25.1  0,0  16.4    04:51  ...    948.8
# 3240       MALAGA        7  25.9  0,0  22.5    05:10  ...   1015.8
# 3241       MALAGA        7  25.9  0,0  22.5    05:10  ...   1015.8
# 3421       MALAGA        7  11.3  0,0   4.7    07:40  ...   1026.6
# 3422       MALAGA        7  11.3  0,0   4.7    07:40  ...   1026.6
# 3602       MALAGA        7  23.9  0,0  19.3    05:10  ...   1013.5
# 3603       MALAGA        7  23.9  0,0  19.3    05:10  ...   1013.5
# 3852      GRANADA      560  27.0  0,0  18.4    05:11  ...    951.3
# 3853      GRANADA      560  27.0  0,0  18.4    05:11  ...    951.3
# 4033      GRANADA      560   5.8  0,0  -4.7    07:10  ...    960.2
# 4034      GRANADA      560   5.8  0,0  -4.7    07:10  ...    960.2
# 4214      GRANADA      560  27.0  0,0  17.2    04:37  ...    948.5
# 4215      GRANADA      560  27.0  0,0  17.2    04:37  ...    948.5
# 4464      CORDOBA       90  27.5  0,0  17.8    04:50  ...   1004.6
# 4465      CORDOBA       90  27.5  0,0  17.8    04:50  ...   1004.6
# 4645      CORDOBA       90   7.1  0,0  -1.8    05:12  ...   1016.2
# 4646      CORDOBA       90   7.1  0,0  -1.8    05:12  ...   1016.2
# 4826      CORDOBA       90  27.8  0,0  17.5    05:13  ...   1001.2
# 4827      CORDOBA       90  27.8  0,0  17.5    05:13  ...   1001.2
# 5076      NAVARRA      459  17.0  0,0  13.5    04:48  ...    970.5
# 5077      NAVARRA      459  17.0  0,0  13.5    04:48  ...    970.5
# 5257      NAVARRA      459   3.4  0,0  -3.5    06:46  ...    971.7
# 5258      NAVARRA      459   3.4  0,0  -3.5    06:46  ...    971.7
# 5438      NAVARRA      459  20.2  0,0  12.8    04:42  ...    965.4
# 5439      NAVARRA      459  20.2  0,0  12.8    04:42  ...    965.4
#
#      horaPresMax presMin  horaPresMin  hrMedia  hrMax  horaHrMax  hrMin  \
# 180       Varias  1017.2           24     73.0   93.0     Varias   55.0
# 181       Varias  1017.2           24     73.0   93.0     Varias   55.0
# 361       Varias  1013.0           15     27.0   77.0      00:18   22.0
# 362       Varias  1013.0           15     27.0   77.0      00:18   22.0
# 542           00  1009.0           24     69.0   99.0     Varias   49.0
# 543           00  1009.0           24     69.0   99.0     Varias   49.0
# 792       Varias  1020.5           24     58.0   93.0      00:43   50.0
# 793       Varias  1020.5           24     58.0   93.0      00:43   50.0
# 973           00  1016.3           12     51.0   95.0      00:01   19.0
# 974           00  1016.3           12     51.0   95.0      00:01   19.0
# 1154          00  1012.4           24     72.0   97.0     Varias   60.0
# 1155          00  1012.4           24     72.0   97.0     Varias   60.0
# 1404      Varias   962.7           24     73.0   96.0      00:11   55.0
# 1405      Varias   962.7           24     73.0   96.0      00:11   55.0
# 1585      Varias   960.8           15     73.0   96.0      00:30   52.0
# 1586      Varias   960.8           15     73.0   96.0      00:30   52.0
# 1766          00   954.5           16     70.0   99.0     Varias   56.0
# 1767          00   954.5           16     70.0   99.0     Varias   56.0
# 2016      Varias  1008.3           17     49.0   74.0      23:52   42.0
# 2017      Varias  1008.3           17     49.0   74.0      23:52   42.0
# 2197      Varias  1015.1           15     65.0   95.0      20:46   26.0
# 2198      Varias  1015.1           15     65.0   95.0      20:46   26.0
# 2378          00  1004.2           17     62.0   80.0      02:56   48.0
# 2379          00  1004.2           17     62.0   80.0      02:56   48.0
# 2628      Varias   949.3           17     36.0   70.0      05:12   22.0
# 2629      Varias   949.3           17     36.0   70.0      05:12   22.0
# 2809      Varias   955.0           15     77.0  100.0      00:12   51.0
# 2810      Varias   955.0           15     77.0  100.0      00:12   51.0
# 2990          00   942.5           18     41.0   77.0     Varias   26.0
# 2991          00   942.5           18     41.0   77.0     Varias   26.0
# 3240          23  1011.4           02     66.0   94.0      04:20   50.0
# 3241          23  1011.4           02     66.0   94.0      04:20   50.0
# 3421          23  1022.2           16     72.0   92.0      08:00   51.0
# 3422          23  1022.2           16     72.0   92.0      08:00   51.0
# 3602          00  1010.6           17     52.0   82.0      22:50   33.0
# 3603          00  1010.6           17     52.0   82.0      22:50   33.0
# 3852      Varias   948.6           17     32.0   69.0     Varias   10.0
# 3853      Varias   948.6           17     32.0   69.0     Varias   10.0
# 4033      Varias   955.8           15     66.0   95.0      07:00   29.0
# 4034      Varias   955.8           15     66.0   95.0      07:00   29.0
# 4214      Varias   944.2           16     32.0   60.0      23:57   19.0
# 4215      Varias   944.2         16.0     32.0   60.0      23:57   19.0
# 4464      Varias  1000.9           17     31.0   80.0     Varias   16.0
# 4465      Varias  1000.9         17.0     31.0   80.0     Varias   16.0
# 4645      Varias  1012.6         15.0     79.0   98.0     Varias   50.0
# 4646      Varias  1012.6           15     79.0   98.0     Varias   50.0
# 4826      Varias   995.8           18     25.0   65.0     Varias   16.0
# 4827      Varias   995.8           18     25.0   65.0     Varias   16.0
# 5076          08   968.2           01     67.0   93.0      00:00   48.0
# 5077          08   968.2           01     67.0   93.0      00:00   48.0
# 5257      Varias   968.1           14     79.0   97.0     Varias   58.0
# 5258      Varias   968.1           14     79.0   97.0     Varias   58.0
# 5438          00   960.1           17     59.0   92.0      00:06   46.0
# 5439          00   960.1           17     59.0   92.0      00:06   46.0
#
#      horaHrMin      city
# 180      14:41    Bilbao
# 181      14:41    Bilbao
# 361      13:42    Bilbao
# 362      13:42    Bilbao
# 542      14:00    Bilbao
# 543      14:00    Bilbao
# 792      13:40  Donostia
# 793      13:40  Donostia
# 973      12:34  Donostia
# 974      12:34  Donostia
# 1154     16:52  Donostia
# 1155     16:52  Donostia
# 1404     14:08   Vitoria
# 1405     14:08   Vitoria
# 1585     15:12   Vitoria
# 1586     15:12   Vitoria
# 1766     14:01   Vitoria
# 1767     14:01   Vitoria
# 2016     15:26  Valencia
# 2017     15:26  Valencia
# 2197     14:52  Valencia
# 2198     14:52  Valencia
# 2378     12:25  Valencia
# 2379     12:25  Valencia
# 2628     16:19    Madrid
# 2629     16:19    Madrid
# 2809     15:56    Madrid
# 2810     15:56    Madrid
# 2990     16:09    Madrid
# 2991     16:09    Madrid
# 3240     17:00    Málaga
# 3241     17:00    Málaga
# 3421     13:30    Málaga
# 3422     13:30    Málaga
# 3602     08:50    Málaga
# 3603     08:50    Málaga
# 3852     12:38   Granada
# 3853     12:38   Granada
# 4033     15:30   Granada
# 4034     15:30   Granada
# 4214     15:33   Granada
# 4215     15:33   Granada
# 4464     15:50   Córdoba
# 4465     15:50   Córdoba
# 4645     16:06   Córdoba
# 4646     16:06   Córdoba
# 4826    Varias   Córdoba
# 4827    Varias   Córdoba
# 5076     10:06  Pamplona
# 5077     10:06  Pamplona
# 5257     15:40  Pamplona
# 5258     15:40  Pamplona
# 5438     13:53  Pamplona
# 5439     13:53  Pamplona
#
# [54 rows x 27 columns]

# %%
#ELIMINAR DUPLICADOS
columnas_duplicados = ['city', 'fecha']
meteorologia = meteorologia.drop_duplicates(subset=columnas_duplicados, keep='first')
duplicados = meteorologia[meteorologia.duplicated(subset=columnas_duplicados, keep=False)]
duplicados
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, fecha, indicativo, nombre, provincia, altitud, tmed, prec, tmin, horatmin, tmax, horatmax, dir, velmedia, racha, horaracha, sol, presMax, horaPresMax, presMin, horaPresMin, hrMedia, hrMax, horaHrMax, hrMin, horaHrMin, city]
# Index: []
#
# [0 rows x 27 columns]

# %%
#Columnas a eliminar
columnas_a_eliminar = [
    'indicativo',      
    'horatmin',       
    'horatmax',       
    'horaracha',      
    'horaPresMax',     
    'horaPresMin',     
    'horaHrMax',       
    'horaHrMin',       
    'nombre',          
]

#Solo eliminar las que existen en el dataframe
columnas_existentes = [col for col in columnas_a_eliminar if col in meteorologia.columns]

#Eliminar columnas
meteorologia = meteorologia.drop(columns=columnas_existentes)

# %%
msno.matrix(meteorologia)

# %%
meteorologia.isna().sum()
# Out:
# Unnamed: 0     0
# fecha          0
# provincia      0
# altitud        0
# tmed          16
# prec           0
# tmin          16
# tmax          10
# dir           17
# velmedia      19
# racha         17
# sol            7
# presMax       14
# presMin       14
# hrMedia       28
# hrMax         22
# hrMin         21
# city           0
# dtype: int64

# %%
df_con_na = meteorologia[meteorologia.isna().any(axis=1)]
df_con_na
# Out:
#       Unnamed: 0       fecha    provincia  altitud  tmed  prec  tmin  tmax  \
# 703          703  2023-04-02     GIPUZKOA        4  12.5  16,1  11.0  14.0
# 706          706  2023-04-05     GIPUZKOA        4   NaN   0,0   NaN   NaN
# 1187        1187  2024-07-26     GIPUZKOA        4  23.0   0,2  21.3  24.6
# 1412        1412  2023-07-07  ARABA/ALAVA      513   NaN   0,4   NaN  30.3
# 2605        2605  2023-06-07       MADRID      609  18.8   6,9  15.8  21.7
# 2716        2716  2023-09-25       MADRID      609  19.6   0,0  10.0  29.1
# 2811        2811  2023-12-28       MADRID      609   2.9   0,0  -2.2   8.0
# 3293        3293  2023-08-21       MALAGA        7  27.0   0,0  23.9  30.2
# 3294        3294  2023-08-22       MALAGA        7   NaN   0,0   NaN   NaN
# 3295        3295  2023-08-23       MALAGA        7  30.2   0,0  26.6  33.9
# 3317        3317  2023-09-14       MALAGA        7  27.8   1,4  24.6  31.1
# 3318        3318  2023-09-15       MALAGA        7  26.3   0,0  23.0  29.6
# 3587        3587  2024-06-09       MALAGA        7   NaN   0,0   NaN  29.1
# 3671        3671  2024-08-31       MALAGA        7   NaN   0,0   NaN   NaN
# 3870        3870  2023-07-17      GRANADA      560  31.8   0,0  19.6  44.1
# 3970        3970  2023-10-25      GRANADA      560  16.6   0,5  12.2  20.9
# 3975        3975  2023-10-30      GRANADA      560   NaN   0,0   NaN   NaN
# 4032        4032  2023-12-26      GRANADA      560   5.6   0,0  -4.7  16.0
# 4097        4097  2024-02-28      GRANADA      560   NaN   0,0   NaN   NaN
# 4230        4230  2024-07-09      GRANADA      560  26.1   0,0  15.4  36.8
# 4371        4371  2023-03-29      CORDOBA       90  18.2   0,0   6.4  30.0
# 4415        4415  2023-05-12      CORDOBA       90  21.2   0,0  11.4  30.9
# 4417        4417  2023-05-14      CORDOBA       90  20.4   0,0  11.0  29.9
# 4577        4577  2023-10-20      CORDOBA       90  16.8   0,0  11.8  21.7
# 4589        4589  2023-11-01      CORDOBA       90   NaN   1,0   NaN  20.3
# 4608        4608  2023-11-20      CORDOBA       90  14.8   0,0   6.9  22.7
# 4743        4743  2024-04-02      CORDOBA       90  13.2   0,0   5.9  20.4
# 4758        4758  2024-04-17      CORDOBA       90  20.2   0,0  11.2  29.1
# 4807        4807  2024-06-05      CORDOBA       90   NaN   0,0   NaN   NaN
# 4808        4808  2024-06-06      CORDOBA       90   NaN   0,0   NaN  40.5
# 4906        4906  2023-01-11      NAVARRA      459   NaN   1,4   NaN   NaN
# 4914        4914  2023-01-19      NAVARRA      459   NaN   7,1   NaN   NaN
# 5028        5028  2023-05-13      NAVARRA      459  11.0  10,5   8.2  13.8
# 5053        5053  2023-06-07      NAVARRA      459  19.6   0,0  13.8  25.5
# 5054        5054  2023-06-08      NAVARRA      459  22.1   0,0  17.4  26.8
# 5139        5139  2023-08-31      NAVARRA      459   NaN   0,0   NaN   NaN
# 5140        5140  2023-09-01      NAVARRA      459   NaN  55,8   NaN  33.9
# 5150        5150  2023-09-11      NAVARRA      459  21.8   6,3  16.2  27.4
# 5207        5207  2023-11-07      NAVARRA      459   NaN   0,2   NaN  11.1
# 5213        5213  2023-11-13      NAVARRA      459  14.6   0,0   8.5  20.8
# 5244        5244  2023-12-14      NAVARRA      459   NaN   3,0   NaN   NaN
# 5245        5245  2023-12-15      NAVARRA      459   9.6    Ip   6.4  12.7
# 5331        5331  2024-03-09      NAVARRA      459   7.5   0,7   1.6  13.4
# 5433        5433  2024-06-19      NAVARRA      459  19.6   8,4  13.7  25.5
# 5497        5497  2024-08-21      NAVARRA      459  20.7   0,0  15.2  26.2
# 5503        5503  2024-08-27      NAVARRA      459  22.2   0,0  12.5  31.9
# 5504        5504  2024-08-28      NAVARRA      459  27.5   0,0  19.4  35.6
# 5506        5506  2024-08-30      NAVARRA      459  23.4  10,3  17.6  29.1
#
#        dir  velmedia  racha   sol  presMax  presMin hrMedia  hrMax hrMin  \
# 703    NaN       NaN    NaN   0.0      NaN      NaN    83.0   96.0  66.0
# 706    NaN       NaN    NaN   9.4      NaN      NaN     NaN    NaN   NaN
# 1187   8.0       2.2    7.8   0.0      NaN      NaN    76.0   88.0  71.0
# 1412  13.0       3.1    9.2  10.2      NaN      NaN     NaN    NaN   NaN
# 2605  14.0       2.5    9.2   NaN    947.4    945.0    85.0   96.0  54.0
# 2716  15.0       1.4    2.8  10.1    954.4    950.9    49.0    NaN   NaN
# 2811   NaN       0.3    NaN   1.2    959.0    956.9    82.0   98.0  62.0
# 3293  12.0       3.9    8.3  11.5   1019.0   1016.0    64.0    NaN   NaN
# 3294  11.0       3.6    8.9   NaN      NaN      NaN     NaN    NaN   NaN
# 3295  13.0       4.4    9.7   NaN      NaN      NaN     NaN    NaN   NaN
# 3317  12.0       3.6    9.2   8.4   1015.5   1011.8    71.0    NaN   NaN
# 3318  11.0       3.6    9.2   7.7   1012.5   1008.6     NaN    NaN   NaN
# 3587  30.0       5.0   11.9   4.0   1012.5   1009.3     NaN    NaN   NaN
# 3671  13.0       2.8    9.2   NaN   1013.0   1010.5     NaN    NaN   NaN
# 3870  99.0       5.3   14.4  13.5    952.6    949.4    22.0    NaN   NaN
# 3970  27.0       1.9    9.2   4.6      NaN      NaN     NaN   96.0  59.0
# 3975   NaN       3.9    NaN   3.0    951.0    941.9    70.0    NaN   NaN
# 4032   NaN       1.4    NaN   8.3    958.9    954.3    69.0   97.0  31.0
# 4097   NaN       NaN    NaN  10.5      NaN      NaN     NaN    NaN   NaN
# 4230  29.0       3.6   11.9   4.9      NaN      NaN    30.0   63.0  18.0
# 4371   NaN       2.2    NaN  11.7   1012.8   1008.3    45.0   88.0  16.0
# 4415   4.0       NaN   16.4  13.0   1003.2    997.2     NaN   71.0  11.0
# 4417  35.0       NaN    9.7  12.2   1008.7   1004.8    33.0   67.0  14.0
# 4577   NaN       NaN    NaN   6.6    999.7      NaN     NaN   94.0  38.0
# 4589  24.0       NaN    9.2   2.8      NaN   1006.6     NaN    NaN  68.0
# 4608  25.0       1.7    4.7   4.9   1011.4   1008.2     NaN   95.0  49.0
# 4743  31.0       2.2    8.6   NaN   1010.4   1006.6    73.0   98.0  48.0
# 4758  23.0       NaN    7.2   NaN   1003.2    999.5     NaN   97.0  36.0
# 4807  20.0       2.8    9.2  14.4   1005.0    999.8     NaN    NaN   NaN
# 4808   8.0       2.5    8.3  13.1   1002.8    997.5     NaN   59.0   NaN
# 4906   NaN       NaN    NaN   0.0      NaN      NaN     NaN    NaN   NaN
# 4914   NaN       3.3    NaN   0.0    963.2    954.3    86.0    NaN   NaN
# 5028   NaN       NaN    NaN   NaN    968.2    966.1     NaN   98.0  60.0
# 5053   NaN       4.2    NaN   1.6    961.9    959.3    63.0   93.0  46.0
# 5054   NaN       4.4    NaN   2.8    968.1    955.9     NaN   72.0  44.0
# 5139   NaN       NaN    NaN   9.8      NaN      NaN     NaN    NaN   NaN
# 5140  15.0       3.1   22.2  10.9    964.6    958.1    49.0    NaN   NaN
# 5150  34.0       NaN   11.4   5.2    964.3    959.4     NaN  100.0  58.0
# 5207   NaN       NaN    NaN   1.6      NaN      NaN     NaN    NaN  56.0
# 5213   NaN       2.5    NaN   4.6    970.7    967.0    79.0   97.0  60.0
# 5244   NaN       4.4    NaN   0.7      NaN      NaN    86.0    NaN   NaN
# 5245  35.0       NaN   10.8   2.0    984.5    979.5     NaN   99.0  72.0
# 5331  12.0       4.4   18.6   3.4    944.6    938.3    62.0    NaN   NaN
# 5433  33.0       NaN   15.3   6.3    964.7    959.9     NaN   92.0  36.0
# 5497  32.0       NaN   10.3   4.2    968.1    964.7     NaN   86.0  46.0
# 5503  18.0       NaN    6.1   7.5    965.3    961.9     NaN   94.0  37.0
# 5504  34.0       NaN   13.3   7.2    964.8    959.5     NaN   85.0  29.0
# 5506  34.0       NaN   13.3   4.6    965.4    962.1     NaN   97.0  53.0
#
#           city
# 703   Donostia
# 706   Donostia
# 1187  Donostia
# 1412   Vitoria
# 2605    Madrid
# 2716    Madrid
# 2811    Madrid
# 3293    Málaga
# 3294    Málaga
# 3295    Málaga
# 3317    Málaga
# 3318    Málaga
# 3587    Málaga
# 3671    Málaga
# 3870   Granada
# 3970   Granada
# 3975   Granada
# 4032   Granada
# 4097   Granada
# 4230   Granada
# 4371   Córdoba
# 4415   Córdoba
# 4417   Córdoba
# 4577   Córdoba
# 4589   Córdoba
# 4608   Córdoba
# 4743   Córdoba
# 4758   Córdoba
# 4807   Córdoba
# 4808   Córdoba
# 4906  Pamplona
# 4914  Pamplona
# 5028  Pamplona
# 5053  Pamplona
# 5054  Pamplona
# 5139  Pamplona
# 5140  Pamplona
# 5150  Pamplona
# 5207  Pamplona
# 5213  Pamplona
# 5244  Pamplona
# 5245  Pamplona
# 5331  Pamplona
# 5433  Pamplona
# 5497  Pamplona
# 5503  Pamplona
# 5504  Pamplona
# 5506  Pamplona

# %%
#1. Identificar columnas numéricas para imputación
all_cols = meteorologia.columns.tolist()
exclude = all_cols[:4] + [all_cols[-1]]
numeric_cols = meteorologia.select_dtypes(include=[np.number]).columns.tolist()
cols_to_impute = [col for col in numeric_cols if col not in exclude]

#2. Contar missing values y eliminar registros con >50% missing
meteorologia['na_count'] = meteorologia[cols_to_impute].isna().sum(axis=1)
total_meteo_cols = len(cols_to_impute)
umbral_eliminar = total_meteo_cols // 2

registros_a_eliminar = meteorologia['na_count'] > umbral_eliminar
meteorologia = meteorologia[~registros_a_eliminar].copy()

print(f"Eliminados {registros_a_eliminar.sum()} registros con >50% missing")

#3. Imputar variables meteorológicas
for col in cols_to_impute:
    if meteorologia[col].isna().any():
        meteorologia[col] = meteorologia[col].fillna(
            meteorologia.groupby('city')[col].transform('mean')
        )
        meteorologia[col] = meteorologia[col].fillna(meteorologia[col].mean())

#4. Eliminar columna temporal
meteorologia = meteorologia.drop('na_count', axis=1)

print(f"Imputación completada. Registros finales: {len(meteorologia)}")
# Out:
# Eliminados 7 registros con >50% missing
# Imputación completada. Registros finales: 5474

# %%
msno.matrix(meteorologia)
plt.savefig('/home/eneko/Imágenes/missing3.png')

# %%
meteorologia.isna().sum()
# Out:
# Unnamed: 0     0
# fecha          0
# provincia      0
# altitud        0
# tmed           0
# prec           0
# tmin           0
# tmax           0
# dir           11
# velmedia       0
# racha          0
# sol            0
# presMax        0
# presMin        0
# hrMedia       22
# hrMax         15
# hrMin         15
# city           0
# dtype: int64

# %%
# onvertir todas las columnas numéricas que estén como strings
for col in meteorologia.columns:
    if meteorologia[col].dtype == 'object':  # Si es string
        # Reemplazar comas por puntos
        meteorologia[col] = meteorologia[col].astype(str).str.replace(',', '.')
        # Intentar convertir a número
        meteorologia[col] = pd.to_numeric(meteorologia[col], errors='ignore')

#Verificar tipos de datos después
print("\nTipos de datos después de la conversión:")
print(meteorologia.dtypes)

#Verificar valores de ejemplo
print("\nValores de ejemplo (primeras filas):")
for col in meteorologia.select_dtypes(include=[np.number]).columns[:5]:
    print(f"{col}: {meteorologia[col].head(3).tolist()}")
# Out:
# Tipos de datos después de la conversión:
# Unnamed: 0      int64
# fecha          object
# provincia      object
# altitud         int64
# tmed          float64
# prec           object
# tmin          float64
# tmax          float64
# dir            object
# velmedia      float64
# racha         float64
# sol           float64
# presMax       float64
# presMin       float64
# hrMedia        object
# hrMax          object
# hrMin          object
# city           object
# dtype: object
#
# Valores de ejemplo (primeras filas):
# Unnamed: 0: [0, 1, 2]
# altitud: [42, 42, 42]
# tmed: [19.2, 9.8, 9.1]
# tmin: [13.4, 5.0, 3.2]
# tmax: [25.1, 14.7, 15.0]

# %%
#Convertir las tres columnas a formato año-mes-dia
reservas['checkin_time'] = pd.to_datetime(reservas['checkin_time']).dt.strftime('%Y-%m-%d')
reservas['checkout_time'] = pd.to_datetime(reservas['checkout_time']).dt.strftime('%Y-%m-%d')
reservas['booked_at'] = pd.to_datetime(reservas['booked_at']).dt.strftime('%Y-%m-%d')

# %%
meteorologia.to_csv(
    "/home/eneko/Documentos/RETO_06/datos/meteo_limpio.csv",
    index=False
)

# %%
reservas.to_csv(
    "/home/eneko/Documentos/RETO_06/datos/reservas.csv",
    index=False
)
